# %%
import ray
from ray.job_submission import JobSubmissionClient, JobStatus
import time

# Ray cluster information
ray_head_ip = "kuberay-head-svc.kuberay.svc.cluster.local"
ray_head_port = 8265
ray_address = f"http://{ray_head_ip}:{ray_head_port}"

for iter in range(1, 20):    
    # Submit Ray job using JobSubmissionClient
    client = JobSubmissionClient(ray_address)
    job_id = client.submit_job(
        entrypoint="python core.py",
        runtime_env={
            "working_dir": "./",
            "pip":["tensorrt", "tensorflow", "nvidia-tensorrt==99.0.0"],
            "env_vars": {"http_proxy":"http://10.78.90.46:80","https_proxy":"http://10.78.90.46:80"}
        },
        entrypoint_num_gpus = 1,
    )

    print(client.__dict__)
    print(f"Ray job submitted with job_id: {job_id}")

    def wait_until_status(job_id, status_to_wait_for, timeout_seconds=5):
        start = time.time()
        while time.time() - start <= timeout_seconds:
            status = client.get_job_status(job_id)
            print(f"status: {status}")
            if status in status_to_wait_for:
                break
            time.sleep(1)


    wait_until_status(job_id, {JobStatus.SUCCEEDED, JobStatus.STOPPED, JobStatus.FAILED})
    logs = client.get_job_logs(job_id)
    print(logs)

    # Wait for a while to let the jobs run
    time.sleep(1)
    job_status = client.get_job_status(job_id)
    get_job_logs = client.get_job_logs(job_id)
    get_job_info = client.get_job_info(job_id)
    async for lines in client.tail_job_logs(job_id):
        print(lines, end="")

    # Shutdown Ray
    ray.shutdown()
# Out:
# 2024-01-22 14:09:48,033	INFO dashboard_sdk.py:338 -- Uploading package gcs://_ray_pkg_6ecc98ea8a4843b4.zip.
# 2024-01-22 14:09:48,035	INFO packaging.py:518 -- Creating a file package for local directory './'.
# {'_client_ray_version': '2.7.0', '_address': 'http://kuberay-head-svc.kuberay.svc.cluster.local:8265', '_cookies': None, '_default_metadata': {}, '_headers': None, '_verify': True, '_ssl_context': None}
# Ray job submitted with job_id: raysubmit_amGmvcsPze1VCymw
# status: PENDING
# status: PENDING
# status: PENDING
# status: RUNNING
# status: RUNNING
# 2024-01-22 06:04:35.183538: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-22 06:04:36.337658: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:04:36.337834: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:04:36.337905: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
#
# 2024-01-22 06:04:35.183538: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-22 06:04:36.337658: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:04:36.337834: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:04:36.337905: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Num GPUs Available:  1
# input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# a: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# b: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# product_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# 2024-01-22 14:10:08,568	INFO dashboard_sdk.py:385 -- Package gcs://_ray_pkg_6ecc98ea8a4843b4.zip already exists, skipping upload.
# {'_client_ray_version': '2.7.0', '_address': 'http://kuberay-head-svc.kuberay.svc.cluster.local:8265', '_cookies': None, '_default_metadata': {}, '_headers': None, '_verify': True, '_ssl_context': None}
# Ray job submitted with job_id: raysubmit_RMbKpKh3NTk2Dkvk
# status: PENDING
# status: PENDING
# status: RUNNING
# status: RUNNING
# status: RUNNING
# 2024-01-22 06:04:55.578898: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-22 06:04:56.724693: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:04:56.724847: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:04:56.724910: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2024-01-22 14:10:15,798	INFO dashboard_sdk.py:385 -- Package gcs://_ray_pkg_6ecc98ea8a4843b4.zip already exists, skipping upload.
# 2024-01-22 06:04:55.578898: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-22 06:04:56.724693: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:04:56.724847: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:04:56.724910: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Num GPUs Available:  1
# input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# a: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# b: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# product_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# {'_client_ray_version': '2.7.0', '_address': 'http://kuberay-head-svc.kuberay.svc.cluster.local:8265', '_cookies': None, '_default_metadata': {}, '_headers': None, '_verify': True, '_ssl_context': None}
# Ray job submitted with job_id: raysubmit_ZXAcG9vxNv713PeL
# status: PENDING
# status: PENDING
# status: RUNNING
# status: RUNNING
# status: RUNNING
# 2024-01-22 06:05:02.663295: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-22 06:05:03.839007: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:03.839167: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:03.839208: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2024-01-22 14:10:23,038	INFO dashboard_sdk.py:385 -- Package gcs://_ray_pkg_6ecc98ea8a4843b4.zip already exists, skipping upload.
# 2024-01-22 06:05:02.663295: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-22 06:05:03.839007: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:03.839167: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:03.839208: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Num GPUs Available:  1
# input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# a: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# b: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# product_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# {'_client_ray_version': '2.7.0', '_address': 'http://kuberay-head-svc.kuberay.svc.cluster.local:8265', '_cookies': None, '_default_metadata': {}, '_headers': None, '_verify': True, '_ssl_context': None}
# Ray job submitted with job_id: raysubmit_2xZZK67ZnMH6UWkY
# status: PENDING
# status: PENDING
# status: RUNNING
# status: RUNNING
# status: RUNNING
# 2024-01-22 06:05:09.986211: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-22 06:05:11.126876: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:11.127030: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:11.127092: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2024-01-22 14:10:30,282	INFO dashboard_sdk.py:385 -- Package gcs://_ray_pkg_6ecc98ea8a4843b4.zip already exists, skipping upload.
# 2024-01-22 06:05:09.986211: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-22 06:05:11.126876: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:11.127030: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:11.127092: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Num GPUs Available:  1
# input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# a: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# b: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# product_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# {'_client_ray_version': '2.7.0', '_address': 'http://kuberay-head-svc.kuberay.svc.cluster.local:8265', '_cookies': None, '_default_metadata': {}, '_headers': None, '_verify': True, '_ssl_context': None}
# Ray job submitted with job_id: raysubmit_HixiasKp319p4dkj
# status: PENDING
# status: PENDING
# status: RUNNING
# status: RUNNING
# status: RUNNING
# 2024-01-22 06:05:17.180992: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-22 06:05:18.349173: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:18.349372: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:18.349422: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2024-01-22 14:10:37,517	INFO dashboard_sdk.py:385 -- Package gcs://_ray_pkg_6ecc98ea8a4843b4.zip already exists, skipping upload.
# 2024-01-22 06:05:17.180992: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-22 06:05:18.349173: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:18.349372: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:18.349422: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Num GPUs Available:  1
# input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# a: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# b: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# product_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# {'_client_ray_version': '2.7.0', '_address': 'http://kuberay-head-svc.kuberay.svc.cluster.local:8265', '_cookies': None, '_default_metadata': {}, '_headers': None, '_verify': True, '_ssl_context': None}
# Ray job submitted with job_id: raysubmit_CccN4MgCce6v2XAD
# status: PENDING
# status: PENDING
# status: RUNNING
# status: RUNNING
# status: RUNNING
# 2024-01-22 06:05:24.311079: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-22 06:05:25.438069: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:25.438223: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:25.438276: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2024-01-22 14:10:44,856	INFO dashboard_sdk.py:385 -- Package gcs://_ray_pkg_6ecc98ea8a4843b4.zip already exists, skipping upload.
# 2024-01-22 06:05:24.311079: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-22 06:05:25.438069: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:25.438223: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:25.438276: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Num GPUs Available:  1
# input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# a: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# b: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# product_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# {'_client_ray_version': '2.7.0', '_address': 'http://kuberay-head-svc.kuberay.svc.cluster.local:8265', '_cookies': None, '_default_metadata': {}, '_headers': None, '_verify': True, '_ssl_context': None}
# Ray job submitted with job_id: raysubmit_fMi5ifmqVR4xa6Nu
# status: PENDING
# status: PENDING
# status: RUNNING
# status: RUNNING
# status: RUNNING
# 2024-01-22 06:05:31.778444: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-22 06:05:32.923939: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:32.924075: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:32.924133: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2024-01-22 14:10:52,128	INFO dashboard_sdk.py:385 -- Package gcs://_ray_pkg_6ecc98ea8a4843b4.zip already exists, skipping upload.
# 2024-01-22 06:05:31.778444: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-22 06:05:32.923939: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:32.924075: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:32.924133: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Num GPUs Available:  1
# input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# a: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# b: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# product_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# {'_client_ray_version': '2.7.0', '_address': 'http://kuberay-head-svc.kuberay.svc.cluster.local:8265', '_cookies': None, '_default_metadata': {}, '_headers': None, '_verify': True, '_ssl_context': None}
# Ray job submitted with job_id: raysubmit_gu1HEgG6X4G1icGi
# status: PENDING
# status: PENDING
# status: RUNNING
# status: RUNNING
# status: RUNNING
# 2024-01-22 06:05:38.960591: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-22 06:05:40.116630: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:40.116773: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:40.116813: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2024-01-22 14:10:59,394	INFO dashboard_sdk.py:385 -- Package gcs://_ray_pkg_6ecc98ea8a4843b4.zip already exists, skipping upload.
# 2024-01-22 06:05:38.960591: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-22 06:05:40.116630: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:40.116773: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:40.116813: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Num GPUs Available:  1
# input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# a: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# b: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# product_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# {'_client_ray_version': '2.7.0', '_address': 'http://kuberay-head-svc.kuberay.svc.cluster.local:8265', '_cookies': None, '_default_metadata': {}, '_headers': None, '_verify': True, '_ssl_context': None}
# Ray job submitted with job_id: raysubmit_16NcCXhgA8hkZmWP
# status: PENDING
# status: PENDING
# status: RUNNING
# status: RUNNING
# status: RUNNING
# 2024-01-22 06:05:46.263498: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-22 06:05:47.403647: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:47.403782: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:47.403821: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2024-01-22 14:11:06,731	INFO dashboard_sdk.py:385 -- Package gcs://_ray_pkg_6ecc98ea8a4843b4.zip already exists, skipping upload.
# 2024-01-22 06:05:46.263498: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-22 06:05:47.403647: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:47.403782: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:47.403821: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Num GPUs Available:  1
# input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# a: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# b: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# product_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# {'_client_ray_version': '2.7.0', '_address': 'http://kuberay-head-svc.kuberay.svc.cluster.local:8265', '_cookies': None, '_default_metadata': {}, '_headers': None, '_verify': True, '_ssl_context': None}
# Ray job submitted with job_id: raysubmit_7H5CCDPKr1v7EqLC
# status: PENDING
# status: PENDING
# status: RUNNING
# status: RUNNING
# status: RUNNING
# 2024-01-22 06:05:53.571565: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-22 06:05:54.744448: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:54.744597: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:54.744638: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2024-01-22 14:11:14,110	INFO dashboard_sdk.py:385 -- Package gcs://_ray_pkg_6ecc98ea8a4843b4.zip already exists, skipping upload.
# 2024-01-22 06:05:53.571565: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-22 06:05:54.744448: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:54.744597: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:05:54.744638: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Num GPUs Available:  1
# input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# a: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# b: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# product_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# {'_client_ray_version': '2.7.0', '_address': 'http://kuberay-head-svc.kuberay.svc.cluster.local:8265', '_cookies': None, '_default_metadata': {}, '_headers': None, '_verify': True, '_ssl_context': None}
# Ray job submitted with job_id: raysubmit_ZrvK6Nf7UvRXwUWK
# status: PENDING
# status: PENDING
# status: PENDING
# status: RUNNING
# status: RUNNING
# 2024-01-22 06:06:01.089942: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-22 06:06:02.239680: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:06:02.239827: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:06:02.239865: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2024-01-22 14:11:21,395	INFO dashboard_sdk.py:385 -- Package gcs://_ray_pkg_6ecc98ea8a4843b4.zip already exists, skipping upload.
# 2024-01-22 06:06:01.089942: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-22 06:06:02.239680: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:06:02.239827: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:06:02.239865: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Num GPUs Available:  1
# input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# a: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# b: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# product_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# {'_client_ray_version': '2.7.0', '_address': 'http://kuberay-head-svc.kuberay.svc.cluster.local:8265', '_cookies': None, '_default_metadata': {}, '_headers': None, '_verify': True, '_ssl_context': None}
# Ray job submitted with job_id: raysubmit_t5GQX3EWm1qEfEmp
# status: PENDING
# status: PENDING
# status: RUNNING
# status: RUNNING
# status: RUNNING
# 2024-01-22 06:06:08.295751: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-22 06:06:09.455813: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:06:09.455966: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:06:09.456016: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2024-01-22 14:11:28,639	INFO dashboard_sdk.py:385 -- Package gcs://_ray_pkg_6ecc98ea8a4843b4.zip already exists, skipping upload.
# 2024-01-22 06:06:08.295751: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-22 06:06:09.455813: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:06:09.455966: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:06:09.456016: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Num GPUs Available:  1
# input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# a: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# b: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# product_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# {'_client_ray_version': '2.7.0', '_address': 'http://kuberay-head-svc.kuberay.svc.cluster.local:8265', '_cookies': None, '_default_metadata': {}, '_headers': None, '_verify': True, '_ssl_context': None}
# Ray job submitted with job_id: raysubmit_hQwVv3HXM28ZpPaQ
# status: PENDING
# status: PENDING
# status: RUNNING
# status: RUNNING
# status: RUNNING
# 2024-01-22 06:06:15.494558: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-22 06:06:16.638060: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:06:16.638213: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:06:16.638274: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2024-01-22 14:11:35,967	INFO dashboard_sdk.py:385 -- Package gcs://_ray_pkg_6ecc98ea8a4843b4.zip already exists, skipping upload.
# 2024-01-22 06:06:15.494558: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-22 06:06:16.638060: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:06:16.638213: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-22 06:06:16.638274: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Num GPUs Available:  1
# input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# a: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# b: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# product_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# Num GPUs Available:  1
# GPU:RESULT tf.Tensor(
# [[22. 28.]
#  [49. 64.]], shape=(2, 2), dtype=float32)
# {'_client_ray_version': '2.7.0', '_address': 'http://kuberay-head-svc.kuberay.svc.cluster.local:8265', '_cookies': None, '_default_metadata': {}, '_headers': None, '_verify': True, '_ssl_context': None}
# Ray job submitted with job_id: raysubmit_pieFRdA57Y5GYzfQ
# status: PENDING
# status: PENDING
# status: RUNNING
# status: RUNNING
