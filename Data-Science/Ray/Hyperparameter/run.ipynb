# %% [markdown]
# # Find Good Hyperparameter For News Recommendation System With Tune
#
# The goal of this example is to train a very simple news recommendation system, We will:
# - Prepare the training data in parallel with Ray
# - Train a simple model that classifies article titles as "popular" or "less popular" using scikit learn and
# - Find good hyperparameter settings for the model with Tune, Ray's parallel hyperparameter optimization library.
#
# ### Downloading And Preparing The Training Data
#
# First we will download and uncompress 400,000 hackernews submissions. This is a small subset of the articles that have been submitted to https://news.ycombinator.com. The data includes the title of each submission and its score, which roughly corresponds to the number of upvotes. There are 4 batches of JSON files that contain the information, named `ls-1.json` through `ls-4.json`. The first couple lines of the first file will be printed below by the `head` command. Delete zip file as we have already extracted the required data.

# %%
# %env
TUNE_DISABLE_STRICT_METRIC_CHECKING=1
RAY_AIR_REENABLE_DEPRECATED_SYNC_TO_HEAD_NODE=1

# %%
import ray
from ray.job_submission import JobSubmissionClient
import time

# Ray cluster information
ray_head_ip = "kuberay-head-svc.kuberay.svc.cluster.local"
ray_head_port = 8265
ray_address = f"http://{ray_head_ip}:{ray_head_port}"

# Submit Ray job using JobSubmissionClient
client = JobSubmissionClient(ray_address)
job_id = client.submit_job(
    entrypoint="python hyperparameter.py",
    runtime_env={
        "working_dir": "./", 
        #"entrypoint_memory": 50000,
        #"excludes": ['']
    },
    entrypoint_num_cpus=3
)
# Out:
# 2024-01-11 12:09:45,264	INFO dashboard_sdk.py:338 -- Uploading package gcs://_ray_pkg_c6239a001d10143c.zip.
# 2024-01-11 12:09:45,266	INFO packaging.py:518 -- Creating a file package for local directory './'.

# %%
print(client.__dict__)
print(f"Ray job submitted with job_id: {job_id}")

# Wait for a while to let the jobs run
time.sleep(10)

job_status = client.get_job_status(job_id)
get_job_logs = client.get_job_logs(job_id)
get_job_info = client.get_job_info(job_id)

async for lines in client.tail_job_logs(job_id):
    print(lines, end="") 
# Disconnect from the Ray cluster
ray.shutdown()
# Out:
# {'_client_ray_version': '2.7.0', '_address': 'http://kuberay-head-svc.kuberay.svc.cluster.local:8265', '_cookies': None, '_default_metadata': {}, '_headers': None, '_verify': True, '_ssl_context': None}
# Ray job submitted with job_id: raysubmit_TF29VHNxULke6KHV
# Took 0.0063669681549072266 seconds to parse the hackernews submissions
# Accuracy on the training set is 1.0
# Accuracy on the test set is 1.0
# 2024-01-11 04:09:55,651	INFO worker.py:1313 -- Using address 10.224.59.219:6379 set in the environment variable RAY_ADDRESS
# 2024-01-11 04:09:55,651	INFO worker.py:1431 -- Connecting to existing Ray cluster at address: 10.224.59.219:6379...
# 2024-01-11 04:09:55,715	INFO worker.py:1612 -- Connected to Ray cluster. View the dashboard at http://10.224.59.219:8265
# 2024-01-11 04:09:55,798	INFO tune.py:666 -- [output] This will use the new output engine with verbosity 2. To disable the new output and use the legacy output engine, set the environment variable RAY_AIR_NEW_OUTPUT=0. For more information, please see https://github.com/ray-project/ray/issues/36949
# ╭───────────────────────────────────────────────────────────────────╮
# │ Configuration for experiment     train_func_2024-01-11_04-09-55   │
# ├───────────────────────────────────────────────────────────────────┤
# │ Search algorithm                 BasicVariantGenerator            │
# │ Scheduler                        AsyncHyperBandScheduler          │
# │ Number of trials                 4                                │
# ╰───────────────────────────────────────────────────────────────────╯
#
# View detailed results here: /home/ray/ray_results/train_func_2024-01-11_04-09-55
# To visualize your results with TensorBoard, run: `tensorboard --logdir /home/ray/ray_results/train_func_2024-01-11_04-09-55`
#
# Trial status: 4 PENDING
# Current time: 2024-01-11 04:09:57. Total running time: 0s
# Logical resource usage: 0/6 CPUs, 0/0 GPUs
# ╭─────────────────────────────────────────────╮
# │ Trial name               status       alpha │
# ├─────────────────────────────────────────────┤
# │ train_func_5547b_00000   PENDING     0.001  │
# │ train_func_5547b_00001   PENDING     0.0001 │
# │ train_func_5547b_00002   PENDING     1e-05  │
# │ train_func_5547b_00003   PENDING     1e-06  │
# ╰─────────────────────────────────────────────╯
#
# Trial train_func_5547b_00000 started with configuration:
# ╭───────────────────────────────────────────────╮
# │ Trial train_func_5547b_00000 config           │
# ├───────────────────────────────────────────────┤
# │ alpha                                   0.001 │
# ╰───────────────────────────────────────────────╯
#
# Trial train_func_5547b_00000 finished iteration 1 at 2024-01-11 04:10:01. Total running time: 4s
# ╭─────────────────────────────────────────────────╮
# │ Trial train_func_5547b_00000 result             │
# ├─────────────────────────────────────────────────┤
# │ time_this_iter_s                        0.02547 │
# │ time_total_s                            0.02547 │
# │ training_iteration                            1 │
# │ mean_accuracy                               0.5 │
# ╰─────────────────────────────────────────────────╯
#
# 2024-01-11 04:10:01,784	WARNING syncer.py:845 -- Ray AIR no longer supports the synchronization of checkpoints and other artifacts from worker nodes to the head node. This means that the checkpoints and artifacts saved by trials scheduled on worker nodes will not be accessible during the run (e.g., resuming from a checkpoint after a failure) or after the run (e.g., loading the checkpoint of a trial that ran on an already terminated worker node).
#
# To fix this issue, configure AIR to use either:
# (1) Cloud storage: `RunConfig(storage_path='s3://your/bucket')`
# (2) A network filesystem mounted on all nodes: `RunConfig(storage_path='/mnt/path/to/nfs_storage')`
# See this Github issue for more details on transitioning to cloud storage/NFS as well as an explanation on why this functionality is being removed: https://github.com/ray-project/ray/issues/37177
# If you are already using NFS, you can ignore this warning message.
#
# Other temporary workarounds:
# - If you want to avoid errors/warnings and continue running with syncing explicitly turned off, set `RunConfig(SyncConfig(syncer=None))`
# - Or, to re-enable the head node syncing behavior, set the environment variable RAY_AIR_REENABLE_DEPRECATED_SYNC_TO_HEAD_NODE=1
#   - **Note that this functionality will tentatively be hard-deprecated in Ray 2.7.** See the linked issue for the latest information.
# Trial train_func_5547b_00000 completed after 1 iterations at 2024-01-11 04:10:01. Total running time: 4s
#
# Trial train_func_5547b_00001 started with configuration:
# ╭────────────────────────────────────────────────╮
# │ Trial train_func_5547b_00001 config            │
# ├────────────────────────────────────────────────┤
# │ alpha                                   0.0001 │
# ╰────────────────────────────────────────────────╯
#
# Trial train_func_5547b_00001 finished iteration 1 at 2024-01-11 04:10:01. Total running time: 4s
# ╭─────────────────────────────────────────────────╮
# │ Trial train_func_5547b_00001 result             │
# ├─────────────────────────────────────────────────┤
# │ time_this_iter_s                        0.00676 │
# │ time_total_s                            0.00676 │
# │ training_iteration                            1 │
# │ mean_accuracy                               0.5 │
# ╰─────────────────────────────────────────────────╯
#
# Trial train_func_5547b_00001 completed after 1 iterations at 2024-01-11 04:10:01. Total running time: 4s
#
# Trial train_func_5547b_00002 started with configuration:
# ╭───────────────────────────────────────────────╮
# │ Trial train_func_5547b_00002 config           │
# ├───────────────────────────────────────────────┤
# │ alpha                                   1e-05 │
# ╰───────────────────────────────────────────────╯
#
# Trial train_func_5547b_00002 finished iteration 1 at 2024-01-11 04:10:01. Total running time: 4s
# ╭─────────────────────────────────────────────────╮
# │ Trial train_func_5547b_00002 result             │
# ├─────────────────────────────────────────────────┤
# │ time_this_iter_s                        0.00653 │
# │ time_total_s                            0.00653 │
# │ training_iteration                            1 │
# │ mean_accuracy                               0.5 │
# ╰─────────────────────────────────────────────────╯
#
# Trial train_func_5547b_00002 completed after 1 iterations at 2024-01-11 04:10:01. Total running time: 4s
#
# (train_func pid=144, ip=10.224.15.163) =========1 0.5
# (train_func pid=144, ip=10.224.15.163) =========2 1    False
# (train_func pid=144, ip=10.224.15.163) 0     True
# (train_func pid=144, ip=10.224.15.163) Name: target, dtype: bool
# (train_func pid=144, ip=10.224.15.163) =========3 1    Computer science and programming are two separ...
# (train_func pid=144, ip=10.224.15.163) 0        The PeopleWeb | Mark Pincus Blog (March 2005)
# (train_func pid=144, ip=10.224.15.163) Name: data, dtype: object
# (train_func pid=144, ip=10.224.15.163) =========1 0.5
# (train_func pid=144, ip=10.224.15.163) =========2 1    False
# (train_func pid=144, ip=10.224.15.163) 0     True
# (train_func pid=144, ip=10.224.15.163) Name: target, dtype: bool
# (train_func pid=144, ip=10.224.15.163) =========3 1    Computer science and programming are two separ...
# (train_func pid=144, ip=10.224.15.163) 0        The PeopleWeb | Mark Pincus Blog (March 2005)
# (train_func pid=144, ip=10.224.15.163) Name: data, dtype: object
# (train_func pid=144, ip=10.224.15.163) =========1 0.5
# (train_func pid=144, ip=10.224.15.163) =========2 1    False
# (train_func pid=144, ip=10.224.15.163) 0     True
# (train_func pid=144, ip=10.224.15.163) Name: target, dtype: bool
# (train_func pid=144, ip=10.224.15.163) =========3 1    Computer science and programming are two separ...
# (train_func pid=144, ip=10.224.15.163) 0        The PeopleWeb | Mark Pincus Blog (March 2005)
# (train_func pid=144, ip=10.224.15.163) Name: data, dtype: objectTrial train_func_5547b_00003 started with configuration:
#
# ╭────────────────────────────────────────────╮
# │ Trial train_func_5547b_00003 config        │
# ├────────────────────────────────────────────┤
# │ alpha                                    0 │
# ╰────────────────────────────────────────────╯
#
# Trial train_func_5547b_00003 finished iteration 1 at 2024-01-11 04:10:01. Total running time: 4s
# ╭─────────────────────────────────────────────────╮
# │ Trial train_func_5547b_00003 result             │
# ├─────────────────────────────────────────────────┤
# │ time_this_iter_s                        0.00571 │
# │ time_total_s                            0.00571 │
# │ training_iteration                            1 │
# │ mean_accuracy                               0.5 │
# ╰─────────────────────────────────────────────────╯
#
# Trial train_func_5547b_00003 completed after 1 iterations at 2024-01-11 04:10:01. Total running time: 4s
#
# Trial status: 4 TERMINATED
# Current time: 2024-01-11 04:10:01. Total running time: 4s
# Logical resource usage: 6.0/6 CPUs, 0/0 GPUs
# Current best trial: 5547b_00000 with mean_accuracy=0.5 and params={'alpha': 0.001}
# ╭───────────────────────────────────────────────────────────────────────────────────╮
# │ Trial name               status         alpha     acc     iter     total time (s) │
# ├───────────────────────────────────────────────────────────────────────────────────┤
# │ train_func_5547b_00000   TERMINATED    0.001      0.5        1         0.025465   │
# │ train_func_5547b_00001   TERMINATED    0.0001     0.5        1         0.0067606  │
# │ train_func_5547b_00002   TERMINATED    1e-05      0.5        1         0.00653458 │
# │ train_func_5547b_00003   TERMINATED    1e-06      0.5        1         0.00571275 │
# ╰───────────────────────────────────────────────────────────────────────────────────╯
#
# (train_func pid=144, ip=10.224.15.163) =========1 0.5
# (train_func pid=144, ip=10.224.15.163) =========2 1    False
# (train_func pid=144, ip=10.224.15.163) 0     True
# (train_func pid=144, ip=10.224.15.163) Name: target, dtype: bool
# (train_func pid=144, ip=10.224.15.163) =========3 1    Computer science and programming are two separ...
# (train_func pid=144, ip=10.224.15.163) 0        The PeopleWeb | Mark Pincus Blog (March 2005)
# (train_func pid=144, ip=10.224.15.163) Name: data, dtype: object
# FINAL SUCCESSFULLY EXECUTED =====  train_func_5547b_00000
