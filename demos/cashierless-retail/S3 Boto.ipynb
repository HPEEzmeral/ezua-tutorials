# %% [markdown]
# # BOTO3

# %%
# | REVIEW: S3 Boto | File: Daily/2023-12-25 | ID: 1703512035 |

# %%
import boto3

# Set up AWS credentials
AWS_ACCESS_KEY = 'minioadmin'
AWS_SECRET_KEY = 'minioadmin'
# External DF
#AWS_ACCESS_KEY = 'PJPPJAU80CTBK3X016WGDACCB'
#AWS_SECRET_KEY = 'YSOACY1RH2SIYC1ML3AKR9OR2S0HTEER8X6X54S73IX9B2TORC3YYLQ7AEH19KB6T4CWLKAIFYWL936NM5DD0U97'

BUCKET_NAME = 'ezaf-demo'

#S3_ENDPOINT_URL = 'https://home.ezua12.ezmeral.demo.local:9000'
#S3_ENDPOINT_URL = 'http://local-s3-service.ezdata-system.svc.cluster.local:30000'
S3_ENDPOINT_URL = 'https://objectstore-zone1-svc.dataplatform.svc.cluster.local:9000'
#S3_ENDPOINT_URL = 'https://ezdf-core1.ezmeral.demo.local:9000'
S3_PATH = 'data/fruit-veg/new/'
S3_DOWNLOADPATH = 'data/fruit-veg/'
LOCAL_FILE_PATH = 'end2end.h5'

s3 = boto3.client(
    's3',
    aws_access_key_id=AWS_ACCESS_KEY,
    aws_secret_access_key=AWS_SECRET_KEY,
    endpoint_url=S3_ENDPOINT_URL,
    verify=False  # Disable SSL certificate verification
)

list_buckets = s3.list_buckets()

for bucket in list_buckets['Buckets']:
        print(bucket['Name'])
# Out:
# ezaf-demo
# mlflow
# /opt/conda/lib/python3.8/site-packages/urllib3/connectionpool.py:1061: InsecureRequestWarning: Unverified HTTPS request is being made to host 'objectstore-zone1-svc.dataplatform.svc.cluster.local'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %%
print( list_buckets)
# Out:
# {'ResponseMetadata': {'RequestId': '1797894925FBA220', 'HostId': '', 'HTTPStatusCode': 200, 'HTTPHeaders': {'accept-ranges': 'bytes', 'content-length': '456', 'content-security-policy': 'block-all-mixed-content', 'content-type': 'application/xml', 'server': 'MinIO', 'vary': 'Origin', 'x-amz-request-id': '1797894925FBA220', 'x-xss-protection': '1; mode=block', 'date': 'Tue, 14 Nov 2023 16:12:11 GMT'}, 'RetryAttempts': 0}, 'Buckets': [{'Name': 'ezaf-demo', 'CreationDate': datetime.datetime(2023, 11, 13, 22, 57, 21, 221000, tzinfo=tzlocal())}, {'Name': 'mlflow', 'CreationDate': datetime.datetime(2023, 11, 11, 18, 20, 36, 921000, tzinfo=tzlocal())}], 'Owner': {'DisplayName': 'minio', 'ID': '02d6176db174dc93cb1b899f7c6078f08654445fe8cf1b6ce98d8855f66bdbf4'}}

# %%
def list_S3(bucketName):
    file_list = s3.

# %%
s3 = boto3.resource('s3', verify=False, endpoint_url=S3_ENDPOINT_URL, 
    aws_access_key_id=AWS_ACCESS_KEY,
    aws_secret_access_key=AWS_SECRET_KEY)

# %%
def downloadDirectoryFroms3(bucketName, remoteDirectoryName):
    bucket = s3.Bucket(bucketName) 
    for obj in bucket.objects.filter(Prefix = remoteDirectoryName):
        if not os.path.exists(os.path.dirname(obj.key)):
            os.makedirs(os.path.dirname(obj.key))
        bucket.download_file(obj.key, obj.key) # save to same path

# %%
downloadDirectoryFroms3('ezaf-demo', '/tmp')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 downloadDirectoryFroms3('ezaf-demo', '/tmp')
#
# Cell In[21], line 2, in downloadDirectoryFroms3(bucketName, remoteDirectoryName)
#       1 def downloadDirectoryFroms3(bucketName, remoteDirectoryName):
# ----> 2     bucket = s3.Bucket(bucketName)
#       3     for obj in bucket.objects.filter(Prefix = remoteDirectoryName):
#       4         if not os.path.exists(os.path.dirname(obj.key)):
#
# File /opt/conda/lib/python3.8/site-packages/botocore/client.py:888, in BaseClient.__getattr__(self, item)
#     885 if event_response is not None:
#     886     return event_response
# --> 888 raise AttributeError(
#     889     f"'{self.__class__.__name__}' object has no attribute '{item}'"
#     890 )
#
# AttributeError: 'S3' object has no attribute 'Bucket'

# %%
my_bucket = s3.bucket('ezaf-demo')
for my_bucket_object in my_bucket.objects.all():
    print(my_bucket_object.key)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 my_bucket = s3.bucket('ezaf-demo')
#       2 for my_bucket_object in my_bucket.objects.all():
#       3     print(my_bucket_object.key)
#
# AttributeError: 's3.ServiceResource' object has no attribute 'bucket'

# %%
import boto3

# Set up AWS credentials
AWS_ACCESS_KEY = 'minioadmin'
AWS_SECRET_KEY = 'minioadmin'
BUCKET_NAME = 'ezaf-demo'

S3_ENDPOINT_URL = 'https://home.ezua12.ezmeral.demo.local:9000'
S3_PATH = 'data/fruit-veg/new/'
S3_DOWNLOADPATH = 'data/fruit-veg/'
LOCAL_FILE_PATH = 'end2end.h5'

s3 = boto3.client(
    's3',
    aws_access_key_id=AWS_ACCESS_KEY,
    aws_secret_access_key=AWS_SECRET_KEY,
    endpoint_url=S3_ENDPOINT_URL,
    verify=False  # Disable SSL certificate verification
)

obj = s3.get_object(Bucket=BUCKET_NAME, Key=LOCAL_FILE_PATH)
content = obj.get()['Body'].read()
print(content.decode('utf-8'))
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File /opt/conda/lib/python3.8/site-packages/urllib3/connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#
# ...

# %%
obj = s3.get_object(Bucket=BUCKET_NAME, Key=LOCAL_FILE_PATH)
content = obj.get()['Body'].read()
print(content.decode('utf-8'))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 obj = s3.get_object(Bucket=BUCKET_NAME, Key=LOCAL_FILE_PATH)
#       2 content = obj.get()['Body'].read()
#       3 print(content.decode('utf-8'))
#
# File /opt/conda/lib/python3.8/site-packages/botocore/client.py:535, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     531     raise TypeError(
#     532         f"{py_operation_name}() only accepts keyword arguments."
#     533     )
#     534 # The "self" in this scope is referring to the BaseClient.
# --> 535 return self._make_api_call(operation_name, kwargs)
#
# File /opt/conda/lib/python3.8/site-packages/botocore/client.py:963, in BaseClient._make_api_call(self, operation_name, api_params)
#     959     maybe_compress_request(
#     960         self.meta.config, request_dict, operation_model
#     961     )
# ...

# %%
import boto3
# Retrieve the list of existing buckets
s3 = boto3.client('s3',verify=False)
response = s3.list_buckets()

# Output the bucket names
print('Existing buckets:')
for bucket in response['Buckets']:
    print(f'  {bucket["Name"]}')
# Out:
# Found credentials in environment variables.
# Found endpoint for s3 via: environment_global.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 3
#       1 import boto3
#       2 # Retrieve the list of existing buckets
# ----> 3 s3 = boto3.client('s3',verify=False)
#       4 response = s3.list_buckets()
#       6 # Output the bucket names
#
# File /opt/conda/lib/python3.8/site-packages/boto3/__init__.py:92, in client(*args, **kwargs)
#      86 def client(*args, **kwargs):
#      87     """
#      88     Create a low-level service client by name using the default session.
#      89
#      90     See :py:meth:`boto3.session.Session.client`.
#      91     """
# ---> 92     return _get_default_session().client(*args, **kwargs)
#
# ...
