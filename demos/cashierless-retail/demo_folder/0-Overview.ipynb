# %% [markdown]
# founder: Dirk Derichsweiler, Contributors: Vincent Charbonnier and Isabelle Steinhauser, September 2023
# # Retail End 2 End Ezmeral Unified Analytics Demo

# %% [markdown]
# ![EZUA-Demo-CTC - Copy.png](attachment:443d75e0-fa2d-4874-9bfe-3e16d0c7e320.png)

# %% [markdown]
# ![Architecture2.png](attachment:8db61c88-6443-4a44-a962-c2327988c87a.png)

# %% [markdown]
# Ezmeral Unified Analytics is a product of HPE. In the following the Key Differentiators are listed ![KeyDifferentiators.png](attachment:bd1a4858-7d7d-4be3-b81a-7bf2527ee2da.png)
